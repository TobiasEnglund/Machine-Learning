# %% [markdown]
# # Naive Bayes

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 

df = pd.read_csv("../Data/spam.csv", encoding="latin-1")
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df_no_nan = df.dropna(axis=1)
df_no_nan.columns = ["class", "content"]
df_no_nan.head()
# Out:
#   class                                            content
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
sns.countplot(data = df_no_nan, x = "class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df = pd.get_dummies(df_no_nan, columns=["class"], drop_first=True)
X, y = df["content"], df["class_spam"]
X.head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: content, dtype: object

# %%
X,y = df_no_nan["content"], df_no_nan["class"]
X.head(), y.head()
# Out:
# (0    Go until jurong point, crazy.. Available only ...
#  1                        Ok lar... Joking wif u oni...
#  2    Free entry in 2 a wkly comp to win FA Cup fina...
#  3    U dun say so early hor... U c already then say...
#  4    Nah I don't think he goes to usf, he lives aro...
#  Name: content, dtype: object,
#  0     ham
#  1     ham
#  2    spam
#  3     ham
#  4     ham
#  Name: class, dtype: object)

# %%
y.head()
# Out:
# 0     ham
# 1     ham
# 2    spam
# 3     ham
# 4     ham
# Name: class, dtype: object

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

tfidf_vectorizer = TfidfVectorizer(stop_words="english")
print(tfidf_vectorizer.get_stop_words())
# Out:
# frozenset({'where', 'noone', 'first', 'may', 'keep', 'sixty', 'three', 'can', 'was', 'become', 'in', 'four', 'someone', 'there', 'must', 'though', 'hereby', 'get', 'third', 'himself', 'mostly', 'neither', 'nine', 'across', 'were', 'except', 'should', 'thence', 'many', 'herein', 'somewhere', 'will', 'through', 'latterly', 'several', 'system', 'six', 'most', 'mill', 'amongst', 'often', 'hundred', 'empty', 'moreover', 'cry', 'again', 'any', 'none', 'another', 'whereby', 'bill', 'because', 'whose', 'nevertheless', 'although', 'mine', 'once', 'how', 'until', 'rather', 'me', 'due', 'thereby', 'among', 'who', 'whatever', 'them', 'part', 'during', 'whence', 'even', 'after', 'anyway', 'now', 'every', 'if', 'not', 'amoungst', 'such', 'least', 'besides', 'others', 'couldnt', 'much', 'than', 'else', 'might', 'on', 'would', 'being', 'those', 'out', 'seemed', 'ltd', 'still', 'why', 'over', 'indeed', 'yet', 'few', 'from', 'nor', 'bottom', 'show', 'con', 'whole', 'around', 're', 'at', 'beforehand', 'two', 'which', 'afterwards', 'ie', 'something', 'by', 'eight', 'eg', 'well', 'becomes', 'meanwhile', 'etc', 'into', 'take', 'the', 'fifty', 'too', 'its', 'then', 'front', 'you', 'anyone', 'full', 'hasnt', 'down', 'twenty', 'sometime', 'side', 'call', 'seem', 'less', 'we', 'see', 'nothing', 'myself', 'whom', 'thru', 'latter', 'hereafter', 'itself', 'of', 'each', 'against', 'that', 'together', 'so', 'whoever', 'more', 'here', 'sincere', 'do', 'top', 'everything', 'both', 'move', 'becoming', 'cannot', 'when', 'back', 'along', 'otherwise', 'own', 'also', 'one', 'co', 'all', 'amount', 'found', 'under', 'between', 'it', 'before', 'to', 'a', 'whereas', 'this', 'he', 'his', 'former', 'fifteen', 'yourself', 'go', 'for', 'seeming', 'us', 'off', 'whereafter', 'am', 'un', 'some', 'already', 'describe', 'elsewhere', 'herself', 'ten', 'onto', 'towards', 'they', 'anywhere', 'she', 'themselves', 'below', 'whereupon', 'seems', 'wherever', 'ourselves', 'forty', 'upon', 'thereafter', 'done', 'about', 'whither', 'him', 'twelve', 'have', 'name', 'my', 'everyone', 'fire', 'formerly', 'hence', 'alone', 'therefore', 'these', 'always', 'their', 'somehow', 'ours', 'has', 'be', 'eleven', 'without', 'serious', 'inc', 'behind', 'find', 'no', 'perhaps', 'while', 'five', 'hers', 'what', 'with', 'almost', 'never', 'up', 'only', 'yours', 'but', 'hereupon', 'within', 'next', 'interest', 'please', 'other', 'whether', 'everywhere', 'last', 'thin', 'your', 'very', 'yourselves', 'our', 'nobody', 'sometimes', 'put', 'her', 'however', 'via', 'or', 'give', 'detail', 'and', 'enough', 'thus', 'could', 'as', 'thick', 'cant', 'per', 'anyhow', 'thereupon', 'whenever', 'beyond', 'an', 'de', 'been', 'fill', 'either', 'therein', 'above', 'namely', 'wherein', 'is', 'are', 'anything', 'became', 'beside', 'ever', 'throughout', 'made', 'toward', 'had', 'further', 'same', 'nowhere', 'since', 'i'})

# %%
X_tfidf = tfidf_vectorizer.fit_transform(X)
X_tfidf
# Out:
# <5572x8404 sparse matrix of type '<class 'numpy.float64'>'
# 	with 43478 stored elements in Compressed Sparse Row format>

# %%
X_tfidf.min(), X_tfidf.max()
# Out:
# (0.0, 1.0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=.33, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((3733, 8404), (1839, 8404))

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
sns.countplot(x=y_train, ax = ax[0])
sns.countplot(x=y_test, ax = ax[1])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ## Naive bayes

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
def evaluate_model(model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred)
    ConfusionMatrixDisplay(cm, display_labels = ["Ham", "Spam"]).plot()

# %%
from sklearn.naive_bayes import MultinomialNB, ComplementNB, BernoulliNB

naive_bayes = dict(
    multinomial=MultinomialNB(), bernouilli=BernoulliNB(), complement=ComplementNB()
)

evaluate_model(naive_bayes["multinomial"])

# recall = TP/(TP+FN)
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98      1587
#         spam       1.00      0.75      0.86       252
#
#     accuracy                           0.97      1839
#    macro avg       0.98      0.88      0.92      1839
# weighted avg       0.97      0.97      0.96      1839

# %%
evaluate_model(naive_bayes["bernouilli"])
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98      1587
#         spam       0.98      0.81      0.89       252
#
#     accuracy                           0.97      1839
#    macro avg       0.97      0.91      0.94      1839
# weighted avg       0.97      0.97      0.97      1839

# %%
evaluate_model(naive_bayes["complement"])
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.99      0.92      0.96      1587
#         spam       0.66      0.94      0.78       252
#
#     accuracy                           0.93      1839
#    macro avg       0.83      0.93      0.87      1839
# weighted avg       0.95      0.93      0.93      1839

# %% [markdown]
# ## Some other models

# %%
from sklearn.svm import LinearSVC

evaluate_model(LinearSVC())
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99      1587
#         spam       0.97      0.85      0.91       252
#
#     accuracy                           0.98      1839
#    macro avg       0.97      0.92      0.95      1839
# weighted avg       0.98      0.98      0.98      1839
# c:\Users\Student\.virtualenvs\GitHub-FsW2I2pH\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier

evaluate_model(RandomForestClassifier())
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.99      1587
#         spam       0.99      0.84      0.91       252
#
#     accuracy                           0.98      1839
#    macro avg       0.98      0.92      0.95      1839
# weighted avg       0.98      0.98      0.98      1839

# %% [markdown]
# ## Combine different models
#
# - majority vote
# - class with most votes wins (hard voting)
# - class with highest probability wins (soft voting)

# %%
from sklearn.ensemble import VotingClassifier

vote_clf = VotingClassifier([
    ("random_forest", RandomForestClassifier()),
    ("svc", LinearSVC()),
    ("naive_complement", ComplementNB()),
    ("naive_multinomial", MultinomialNB()),
    ("naive_bernouilli", BernoulliNB())
], voting = "hard")

evaluate_model(vote_clf)
# Out:
# c:\Users\Student\.virtualenvs\GitHub-FsW2I2pH\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99      1587
#         spam       1.00      0.85      0.92       252
#
#     accuracy                           0.98      1839
#    macro avg       0.99      0.92      0.95      1839
# weighted avg       0.98      0.98      0.98      1839

# %% [markdown]
# ## Testing out a model - "deploy"
#
# - assume we choose vote_clf

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([("tfidf", TfidfVectorizer(stop_words="english")), ("vote", vote_clf)])

# fits on all data
pipe.fit(X,y)
pipe.predict(["Come and collect your $1000 Bitcoins!"])
# Out:
# c:\Users\Student\.virtualenvs\GitHub-FsW2I2pH\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# array(['ham'], dtype=object)

# %%
pipe.predict(["You will win, $1000 for free"])
# Out:
# array(['spam'], dtype=object)

# %%
pipe.predict(["love bitcoin"])
# Out:
# array(['ham'], dtype=object)

# %%
pipe.predict(["You get €500"])
# Out:
# array(['spam'], dtype=object)
